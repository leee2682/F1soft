# %%
import pandas as pd
import openpyxl
import shutil
import json
import os

wb = openpyxl.Workbook()

ws = wb.active

ws['A1'] = 'Class'
ws['B1'] = 'State'
ws['C1'] = 'FileName'

path = r'F:\TTA\원천데이터'
a = r'D:\none'

i = 1
b = 0

for state in os.listdir(path):
    for cls in os.listdir(os.path.join(path, state)):
        for file in os.listdir(os.path.join(path, state, cls)):
            i += 1
            b += 1
            # ws.cell(i, 1, state.split('.')[1])
            # ws.cell(i, 2, cls.split('.')[1])
            # ws.cell(i, 3, file)
            ws.cell(i, 1, file)
        print(f'{state[4:]}/\t{cls[3:]} : {b}개')
        b = 0

# for file in os.listdir(a):
#     i += 1
#     b += 1
#     ws.cell(i, 1, file.split('_')[1])
#     ws.cell(i, 2, file.split('_')[2])
#     ws.cell(i, 3, file)
# print(f"{file.split('_')[1]}/\t{file.split('_')[2]} : {b}개")
# b = 0

print(f'총 {i - 1}개')
wb.save('C:/Users/admin/Desktop/119_sample_log.xlsx')
# Out:
# /	0 : 1000개
# /	1 : 1000개
# /	0 : 2000개
# /	1 : 2000개
# /	0 : 1000개
# /	1 : 2000개
# /	0 : 2000개
# /	1 : 2000개
# /	0 : 2000개
# /	1 : 2000개
# /	0 : 1000개
# /	1 : 1000개
# /	0 : 2000개
# /	1 : 2000개
# /	0 : 1000개
# /	1 : 2000개
# /	0 : 2000개
# /	1 : 2000개
# /	0 : 1000개
# /	1 : 2000개
# /	0 : 2000개
# /	1 : 2000개
# /	0 : 2000개
# /	1 : 2000개
# /	0 : 2000개
# /	1 : 2000개
# /	0 : 1000개
# /	1 : 2000개
# /	0 : 1000개
# /	1 : 1000개
# /	0 : 2000개
# /	1 : 2000개
# /	0 : 1000개
# /	1 : 1000개
# /	0 : 1000개
# /	1 : 1000개
# /	0 : 2000개
# /	1 : 2000개
# /	0 : 2000개
# /	1 : 2000개
# /	0 : 1000개
# /	1 : 2000개
# /	0 : 1000개
# /	1 : 1000개
# /	0 : 2000개
# /	1 : 2000개
# /	0 : 2000개
# /	1 : 2000개
# /	0 : 2000개
# /	1 : 2000개
# /	0 : 1000개
# /	1 : 2000개
# /	0 : 2000개
# /	1 : 2000개
# /	0 : 1000개
# /	1 : 2000개
# /	0 : 2000개
# /	1 : 2000개
# /	0 : 1000개
# /	1 : 2000개
# 총 100000개
