# %%
import pandas as pd
import openpyxl
from tqdm import tqdm
import shutil
import json
import os

wb = openpyxl.Workbook()

ws = wb.active

ws['A1'] = '라벨링데이터'
ws['E1'] = '원천데이터'

def file_num(folder_path):
    folder_lst = os.listdir(folder_path)

    x = 1
    i, j = 0, 0

    for folder in tqdm(folder_lst):
        if (folder == 'None'):
            folder = folder_path + folder
            file_lst = os.listdir(folder)

            for file in file_lst:
                    i += 1
                    j += 1

            if (file.split('.')[-1] == 'json'):
                ws.cell(62, 1, 'None')
                ws.cell(62, 3, i)
            if (file.split('.')[-1] == 'jpg'):
                ws.cell(62, 5, 'None')
                ws.cell(62, 7, i)
            print('None = {}'.format(i))
            j = i - j
            i = 0
        else:
            folder = folder_path + folder
            folder_lst2 = os.listdir(folder)
    
            for folder2 in folder_lst2:
                folder2 = folder + '/' + folder2 + '/'
                file_lst = os.listdir(folder2)
            
                for file in file_lst:
                    i += 1
                    j += 1
            
                x += 1
                if (file.split('.')[-1] == 'json'):
                    ws.cell(x, 1, folder2.split('/')[-3][:2])
                    ws.cell(x, 2, folder2.split('/')[-2][:1])
                    ws.cell(x, 3, i)

                elif (file.split('.')[-1] == 'jpg'):
                    ws.cell(x, 5, folder2.split('/')[-3][:2])
                    ws.cell(x, 6, folder2.split('/')[-2][:1])
                    ws.cell(x, 7, i)

                i = 0

    if (file.split('.')[-1] == 'json'):
        print('라벨링데이터 - {}'.format(abs(j)))
    elif (file.split('.')[-1] == 'jpg'):
        print('원천데이터 - {}'.format(abs(j)))

file_num(r'F:\TTA\라벨링데이터/')
file_num(r'F:\TTA/원천데이터/')

wb.save(r'C:/Users/admin/Desktop/73.xlsx')

# %%
import pandas as pd
from openpyxl import load_workbook
import shutil
import json
import os

load_wb = load_workbook(r'C:/Users/admin/Desktop/dddd.xlsx', data_only=True)

load_ws = load_wb['Sheet1']

i = 0
file_lst = os.listdir(path)

for row in load_ws.rows:
    i += 1
    if('1_01_1_1_01_1_20210720_0000033946.jpg' == row[1].valuimport pandas as pd
import openpyxl
from tqdm import tqdm
import shutil
import json
import os

wb = openpyxl.Workbook()

ws = wb.active

ws['A1'] = '라벨링데이터'
ws['E1'] = '원천데이터'

def file_num(folder_path):
    folder_lst = os.listdir(folder_path)

    x = 1
    i, j = 0, 0

    for folder in tqdm(folder_lst):
        if (folder == 'None'):
            folder = folder_path + folder
            file_lst = os.listdir(folder)

            for file in file_lst:
                    i += 1
                    j += 1

            if (file.split('.')[-1] == 'json'):
                ws.cell(62, 1, 'None')
                ws.cell(62, 3, i)
            if (file.split('.')[-1] == 'jpg'):
                ws.cell(62, 5, 'None')
                ws.cell(62, 7, i)
            print('None = {}'.format(i))
            j = i - j
            i = 0
        else:
            folder = folder_path + folder
            folder_lst2 = os.listdir(folder)
    
            for folder2 in folder_lst2:
                folder2 = folder + '/' + folder2 + '/'
                file_lst = os.listdir(folder2)
            
                for file in file_lst:
                    i += 1
                    j += 1
            
                x += 1
                if (file.split('.')[-1] == 'json'):
                    ws.cell(x, 1, folder2.split('/')[-3][:2])
                    ws.cell(x, 2, folder2.split('/')[-2][:1])
                    ws.cell(x, 3, i)

                elif (file.split('.')[-1] == 'jpg'):
                    ws.cell(x, 5, folder2.split('/')[-3][:2])
                    ws.cell(x, 6, folder2.split('/')[-2][:1])
                    ws.cell(x, 7, i)

                i = 0

    if (file.split('.')[-1] == 'json'):
        print('라벨링데이터 - {}'.format(abs(j)))
    elif (file.split('.')[-1] == 'jpg'):
        print('원천데이터 - {}'.format(abs(j)))

file_num(r'F:\라벨링데이터/')
file_num(r'F:/원천데이터/')

wb.save(r'C:/Users/admin/Desktop/73.xlsx')e):
        print(row[4].value)
        load_ws.delete_rows(i)
        
        load_wb.save(r'C:/Users/admin/Desktop/dddd.xlsx')
        
        try:
            src = os.path.join(path, file)
            dst = rows[0]['filename']
            print(dst)
            dst = os.path.join(move_path + dst[2:4] + '/' + dst[-7:-6] + '/' + dst[-9:-8], dst)
            os.rename(src, dst)

# %%
import os
from tqdm import tqdm

lab = r'F:\none/'
re = r'F:\원천데이터/'

for folder in os.listdir(re):
    for folder2 in os.listdir(os.path.join(re, folder)):
        for refine in os.listdir(os.path.join(os.path.join(re, folder), folder2)):
            if (refine.split('.')[-1] != 'jpg' and refine.split('.')[-1] != 'jpeg'):
                src = os.path.join(os.path.join(re + folder, folder2), refine)
                dst = os.path.join(lab, refine)
                
                os.rename(src, dst)

# %%
import pandas as pd
import pymysql
import shutil
import os

host = '218.155.74.39'
iid ='root'
pw = 'f1soft@170'
db_name = 'aihub_video_73'

conn = pymysql.connect(host=host, user= iid, password=pw, db=db_name, charset='utf8')

curs = conn.cursor(pymysql.cursors.DictCursor)

path = r'F:/120/data_211224/dataset/'
move_path = r'F:/120/원천데이터/'

file_lst = os.listdir(path)

for file in file_lst:
    filepath = path + '/' + file
    
    sql = """
        SELECT filename
          FROM  TEST
          WHERE file LIKE '%s'
    """%(file)
    
    curs.execute(sql)

    rows = curs.fetchall()

    try:
        src = os.path.join(path, file)
        dst = rows[0]['filename']
        print(dst)
        dst = os.path.join(move_path + dst[-5:-4] + '/' + dst[-7:-6] + '/' + dst[-9:-8], dst)
        os.rename(src, dst)
        
    except:
        src = os.path.join(path, file)
        dst = file
        dst = os.path.join(move_path + 'none/', dst)
        shutil.move(src, dst)

# %%
import pandas as pd
import openpyxl
import shutil
import json
import os

wb = openpyxl.Workbook()

ws = wb.active

ws['A1'] = 'filename'

path = r'C:/Users/admin/Desktop/NIA73/라벨링데이터/'

folder_lst = os.listdir(path)

i = 1

for folder in folder_lst:
    folder = path + folder
    folder_lst2 = os.listdir(folder)
    
    for folder2 in folder_lst2:
        folder2 = folder + '/' + folder2 + '/'
        file_lst = os.listdir(folder2)
        
        for file in file_lst:
            i += 1
            src = os.path.join(folder2, file)
            
            with open(src, 'r', encoding = 'UTF8') as f:
                data = json.load(f)

            ws.cell(i, 1, data['info']['filename'])
            
wb.save(r'C:/Users/admin/Desktop/73log.xlsx')

# %%
import pandas as pd
import pymysql
import os

host = '218.155.74.39'
iid ='root'
pw = 'f1soft@170'
db_name = 'aihub_video_73'

conn = pymysql.connect(host=host, user= iid, password=pw, db=db_name, charset='utf8')

curs = conn.cursor(pymysql.cursors.DictCursor)

path = r'H:/원천데이터/16/'

folder_lst = os.listdir(path)

for folder in folder_lst:
    folder = path + folder + '/'
    file_lst = os.listdir(folder)
    
    for file in file_lst:
        src = os.path.join(folder, file)
        
        sql = '''
            SELECT filename
            FROM TEST
            WHERE filename LIKE '%s'
        '''%(file[:5] + '_' + file[6:9] + '_' + file[-26:])
        
        curs.execute(sql)

        rows = curs.fetchall()
        
        try:
            filename = rows[0]['filename']
            dst = os.path.join(folder, filename)
            os.rename(src, dst)

            print('success', filename)
        except:
            print('failed', file)

# %%
import pandas as pd
import openpyxl

df = pd.read_excel(r'C:/Users/admin/Desktop/dd.xlsx', sheet_name="Sheet", engine='openpyxl')

df['aa'] = '1'

df.to_excel(r'C:/Users/admin/Desktop/dd.xlsx', sheet_name="Sheet", index = False)

# %%
import pandas as pd
import openpyxl
import shutil
import json
import os

Label_path = r'C:/Users/admin/Desktop/NIA73/라벨링데이터/'

Refine_path = r'H:/원천데이터/'

Label_lst = os.listdir(Label_path)
Refine_lst = os.listdir(Refine_path)

i = 0
k = 0

for Label in Label_lst:
    Label = Label_path + Label
    Label_lst2 = os.listdir(Label)
    
    for Label2 in Label_lst2:
        Label2 = Label + '/' + Label2 + '/'
        file_lst = os.listdir(Label2)
        
        for file in file_lst:
            i += 1

for Refine in Refine_lst:
    Refine = Refine_path + Refine
    Refine_lst2 = os.listdir(Refine)
    
    for Refine2 in Refine_lst2:
        Refine2 = Refine + '/' + Refine2 + '/'
        file_lst2 = os.listdir(Refine2)
        
        for file2 in file_lst2:
            k += 1
print('119', '\n라벨링데이터 -', i, '\n원천데이터   -', k, '\n{}'.format(abs(i - k)))

# %%
## 숫자 -> 한글명 Rename
import os

root_folder = r'H:/원천데이터/'

class_list = {
    '01': '01. Bollard_스테인리스',
    '02': '02. Bollard_탄성고무',
    '03': '03. 시선유도봉_2줄',
    '04': '04. 시선유도봉_3줄',
    '05': '05. 보행자용 방호울타리',
    '06': '06. 교량용 방호울타리',
    '07': '07. 턱낮추기',
    '08': '08. 경사로',
    '09': '09. 점자블럭',
    '10': '10. (도로안내표지) 지주',
    '11': '11. 보도(시멘트 콘크리트)',
    '12': '12. 보도 블록',
    '13': '13. 자전거 도로',
    '14': '14. 연석',
    '15': '15. 무단횡단 방지 울타리',
    '16': '16. 맨홀',
    '17': '17. 중앙차로 버스정차대',
    '18': '18. 가로변 버스정차대',
    '19': '19. 가로변 택시정차대',
    '20': '20. 방음벽',
    '21': '21. 현장 신호제어기',
    '22': '22. 보행자 작동신호기',
    '23': '23. 시각장애인용 음향신호기',
    '24': '24. 과속방지턱',
    '25': '25. 횡단보도',
    '26': '26. 고원식횡단보도',
    '27': '27. 통합표지',
    '28': '28. 정주식, 부착식 표지',
    '29': '29. (가로등) 지주',
    '30': '30. (전봇대) 빗금표시',
    '31': '31. Bollard_대리석',
    '32': '32. Bollard_U자형',
    '36': '36. 소화전',
    '37': '37. 주차멈춤턱_블럭형',
    '38': '38. 보행자_계단',
}

defect_list = {
    '0': '0. 양호',
    '1': '1. 불량'
}

Rclass_list = {
    '01. Bollard_스테인리스' : '01',
    '02. Bollard_탄성고무' : '02',
    '03. 시선유도봉_2줄' : '03',
    '04. 시선유도봉_3줄' : '04',
    '05. 보행자용 방호울타리' : '05',
    '06. 교량용 방호울타리' : '06',
    '07. 턱낮추기' : '07',
    '08. 경사로' : '08',
    '09. 점자블럭' : '09',
    '10. (도로안내표지) 지주' : '10',
    '11. 보도(시멘트 콘크리트)' : '11',
    '12. 보도 블록' : '12',
    '13. 자전거 도로' : '13',
    '14. 연석' : '14',
    '15. 무단횡단 방지 울타리' : '15',
    '16. 맨홀' : '16',
    '17. 중앙차로 버스정차대' : '17',
    '18. 가로변 버스정차대' : '18',
    '19. 가로변 택시정차대' : '19',
    '20. 방음벽' : '20',
    '21. 현장 신호제어기' : '21',
    '22. 보행자 작동신호기' : '22',
    '23. 시각장애인용 음향신호기' : '23',
    '24. 과속방지턱' : '24',
    '25. 횡단보도' : '25',
    '26. 고원식횡단보도' : '26',
    '27. 통합표지' : '27',
    '28. 정주식, 부착식 표지' : '28',
    '29. (가로등) 지주' : '29',
    '30. (전봇대) 빗금표시' : '30',
    '31. Bollard_대리석' : '31',
    '32. Bollard_U자형' : '32',
    '36. 소화전' : '36',
    '37. 주차멈춤턱_블럭형' : '37',
    '38. 보행자_계단' : '38',
}

Rdefect_list = {
    '0. 양호': '0',
    '1. 불량': '1'
}

#num to txt
def num2txt():
    for facility in os.listdir(root_folder):
        for defect in os.listdir(os.path.join(root_folder, facility)):
            old_name = os.path.join(root_folder, facility, defect)
            new_name = os.path.join(root_folder, class_list[f'{facility}'], defect_list[f'{defect}'])
            os.renames(old_name, new_name)

#txt to num
def txt2num():
    for facility in os.listdir(root_folder):
        for defect in os.listdir(os.path.join(root_folder, facility)):
            old_name = os.path.join(root_folder, facility, defect)
            new_name = os.path.join(root_folder, Rclass_list[f'{facility}'], Rdefect_list[f'{defect}'])
            os.renames(old_name, new_name)
    

num2txt()

# %%
import pandas as pd
from openpyxl import load_workbook
import openpyxl
import pymysql
from tqdm import tqdm
import os


wb = load_workbook(filename = 'C:/Users/admin/Desktop/ㅇㅇㅇ.xlsx', read_only = False, data_only = False)

print(wb)

# wb.save('C:/Users/admin/Desktop/블랙박스_유형별_시간.xlsx')

# %%
import pandas as pd
import openpyxl

df = pd.read_excel(r'C:/Users/admin/Desktop/블랙박스_유형별_시간.xlsx', sheet_name="시간 추출", engine='openpyxl')

df

# wb.save('C:/Users/admin/Desktop/블랙박스_유형별_시간.xlsx')

# df.to_excel(r'C:/Users/admin/Desktop/dd.xlsx', sheet_name="Test", index = False)

# %%
df[0:9]

# %%
import pymysql

host = '218.155.74.39'
iid ='root'
pw = 'f1soft@170'
db_name = 'aihub_video_73'

conn = pymysql.connect(host=host, user= iid, password=pw, db=db_name, charset='utf8')

curs = conn.cursor(pymysql.cursors.DictCursor)

a = "_".join(input()) + ".mp4"
fn = ""

while fn != "0":
    fn = "_".join(input('조회 목록 : '))
    if fn != "0":
        a += "|" + fn + ".mp4"

sql = f"""
    SELECT * 
    FROM DATA AS A JOIN DATA_DETAIL AS B
        ON A.DATA_ID= B.DATA_ID
    WHERE (A.CONFIRM_STATUS=0)
        AND (B.DEVICE= 1 OR B.DEVICE= 2)
    AND (A.FILENAME NOT REGEXP "{a}")
"""

curs.execute(sql)

rows = curs.fetchall()

print(len(rows))

# %%
import shutil
import json
import os

refine = './test/'
label = './2. Label/'
move = './ss/'

re_lst = []

for folder in os.listdir(refine):
    for folder2 in os.listdir(os.path.join(refine, folder)):
        filenema = folder2.split('_')
        re_lst.append("{}_{}".format(filenema[-2], filenema[-1].split('.')[0]))

for folder in os.listdir(label):
    for folder2 in os.listdir(os.path.join(label, folder)):
        for file in os.listdir(os.path.join(os.path.join(label, folder), folder2)):
            files = file.split('.')[0]
            laname = files.split('_')
            la_file = '{}_{}'.format(laname[-2], laname[-1])
            if la_file in re_lst:
                src = os.path.join(os.path.join(label, folder), folder2) + '/' + file
                dst = os.path.join(move, file)
                shutil.copy(src, dst)
                print(folder2, file)

# %%
__author__ = 'Seran'
 
import cv2
 
# 영상의 의미지를 연속적으로 캡쳐할 수 있게 하는 class
vidcap = cv2.VideoCapture(r'C:\Users\admin\Downloads\비식별화 샘플\MATRIX_CCTV/M010000_000_1_0_8.mp4')

fps = vidcap.get(cv2.CAP_PROP_FPS)
length = int(vidcap.get(cv2.CAP_PROP_FRAME_COUNT))
 
count = 0
 
while(vidcap.isOpened()):
    ret, image = vidcap.read()
 
    if(int(vidcap.get(1)) % int(fps/2) == 0):
        print('Saved frame number : ' + str(int(vidcap.get(1))))
        cv2.imwrite("../images/frame%d.jpg" % count, image)
        print('Saved frame%d.jpg' % count)
        count += 1
        
        print(int(vidcap.get(1)))
        
vidcap.release()

# %%
import cv2
import os

videoPath = r'C:\Users\admin\Downloads\비식별화 샘플\MATRIX_CCTV/'
imagePath = r'C:\Users\admin\Desktop\sample/'
file_list = os.listdir(videoPath)

lst = []

for file in file_list:
    try:
        if not (os.path.isdir(videoPath + file)):
            os.makedirs(os.path.join(imagePath + file))

            cap = cv2.VideoCapture(videoPath + file)

            count = 0

            while True:
                ret, image = cap.read()

                if not ret:
                    break

                if(str(image) not in lst):
                            cv2.imwrite(imagePath + file + "/frame%d.jpg" % count, image)
                            lst.append(str(image))
                            print('Saved frame%d.jpg' % count)
                            count += 1

            cap.release()

    except OSError as e:
        if e.errno != e.EEXIST:
            print("Failed to create directory!!!!!")
            raise
# Out:
# Saved frame0.jpg
# Saved frame1.jpg
# Saved frame2.jpg
# Saved frame3.jpg
# Saved frame4.jpg
# Saved frame5.jpg
# Saved frame6.jpg
# Saved frame7.jpg
# Saved frame8.jpg
# Saved frame9.jpg
# Saved frame10.jpg
# Saved frame11.jpg
# Saved frame12.jpg
# Saved frame13.jpg
# Saved frame14.jpg
# Saved frame15.jpg
# Saved frame16.jpg
# Saved frame17.jpg
# Saved frame18.jpg
# Saved frame19.jpg
# Saved frame20.jpg
# Saved frame21.jpg
# Saved frame22.jpg
# Saved frame23.jpg
# Saved frame24.jpg
# Saved frame25.jpg
# Saved frame26.jpg
# Saved frame27.jpg
# Saved frame28.jpg
# Saved frame29.jpg
# Saved frame30.jpg
# Saved frame31.jpg
# Saved frame32.jpg
# Saved frame33.jpg
# Saved frame34.jpg
# Saved frame35.jpg
# Saved frame36.jpg
# Saved frame37.jpg
# Saved frame38.jpg
# Saved frame39.jpg
# Saved frame40.jpg
# Saved frame41.jpg
# Saved frame42.jpg
# Saved frame43.jpg
# Saved frame44.jpg
# Saved frame45.jpg
# Saved frame46.jpg
# Saved frame47.jpg
# Saved frame48.jpg
# Saved frame49.jpg
# ...

# %%
import numpy as np
import cv2
import os

videoPath = r'C:\Users\admin\Downloads\비식별화 샘플/'
imagePath = r'C:\Users\admin\Desktop\sample/'
nonePath = r'C:\Users\admin\Desktop\none/'

lst = []

for cls in os.listdir(videoPath):
    for file in os.listdir(os.path.join(videoPath, cls)):
        try:
            if not (os.path.isdir(os.path.join(videoPath, cls, file))):
                os.makedirs(os.path.join(imagePath, cls, file))

                cap = cv2.VideoCapture(os.path.join(videoPath, cls, file))
                
                fps = cap.get(cv2.CAP_PROP_FPS)
                length = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))


                count = 1

                while(cap.isOpened()):
                    ret, image = cap.read()
            
                    if(int(cap.get(1)) % int(fps/2) == 0):
                        if(int(cap.get(1)) >= length - (fps/2)):
                            break
                        
                        print('Saved frame number : ' + str(int(cap.get(1))))
                        
                        if(str(image) not in lst):
                            cv2.imwrite(os.path.join(imagePath, cls, file) + "/frame%d.jpg" % count, image)
                            lst.append(str(image))
                            print('Saved frame%d.jpg' % count)
                            count += 1
                cap.release()

        except OSError as e:
            if e.errno != e.EEXIST:
                print("Failed to create directory!!!!!")
                raise

# %%
import cv2
import os
import pymysql
import numpy as np
from PIL import Image
from tqdm import tqdm
from filecmp import cmp

def connect():
    db_info = pymysql.connect(
        user='root',
        passwd='f1soft@170',
        host='218.155.74.39',
        db='aihub_video_73',
        charset='utf8'
    )
    cursor = db_info.cursor(pymysql.cursors.DictCursor)
    return db_info, cursor


def select(query):
    try:
        db_info, cursor = connect()
        sql = query
        cursor.execute(sql)
        result = cursor.fetchall()
        db_info.close()
        return result
    except:
        return None

ret = select('''SELECT  
      -- A.IS_BLUR,
      CASE WHEN A.IS_BLUR = 1 THEN CONCAT('blur_dataset/',A.DATASET_ID,'/',SUBSTRING_INDEX(SUBSTRING_INDEX(A.PATH,'/',-1),'.',1),'_blur.mp4') ELSE A.PATH END AS PATH
      #CASE WHEN A.IS_BLUR IS NULL THEN CONCAT('blur_dataset/',A.DATASET_ID,'/',SUBSTRING_INDEX(SUBSTRING_INDEX(A.PATH,'/',-1),'.',1),'_blur.mp4') ELSE A.PATH END AS PATH,
      -- A.FILENAME,
      -- B.CLIP_ID,
      -- B.DEVICE,
      -- B.DATE,
      -- B.WEATHER,
      -- B.IS_SCRIPTED,
      -- B.TIME,
      -- B.VIOLATION,
      -- B.VEHICLE,
      -- B.ACCIDENT_TYPE,
      -- A.CREATED_DATE,      
      -- A.DURATION
FROM DATA A 
LEFT JOIN DATA_DETAIL B
ON A.DATA_ID = B.DATA_ID
LEFT JOIN DATASET C
ON A.DATASET_ID = C.DATASET_ID
WHERE B.DATA_ID IS NOT NULL
AND C.TITLE LIKE '%abies%'
AND A.CONFIRM_STATUS = 4
AND B.DEVICE IN (1,2,3,4)
AND B.WEATHER IN (0,1)
AND B.IS_SCRIPTED IN (0,1)
AND B.TIME IN (0,1)
AND B.VIOLATION IN (0,1)
AND B.VEHICLE IN (0,1,2,3)
AND B.ACCIDENT_TYPE IN (1,2,3,4,5,6,7,8)
''')

videoPath = './video/'
imagePath = './image/'

# file_list = os.listdir(videoPath)
file_list = []

for i in ret:
    # print('X:/'+i['PATH'])
    file_list.append('Z:/'+i['PATH'])

lst = [] # frame
with tqdm(total=len(file_list)) as pbar:
    for file in file_list:
        try:
            # if not (os.path.isdir(videoPath + file)):
            #     os.makedirs(os.path.join(imagePath + file))

            cap = cv2.VideoCapture(file)

            fps = cap.get(cv2.CAP_PROP_FPS)
            length = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
            
            count = 1

            while (cap.isOpened()):
                ret, image = cap.read()

                # if (int(cap.get(1)) % int(fps / 2) == 0):
                if (int(cap.get(1)) % int(length/7) == 0):
                    if (int(cap.get(1)) > length - int(length/7)):
                        break
                    if str(image) not in lst:
                        if os.path.isfile('Z:/test/'+ str(file.split('/')[-1].split('.')[0]) + '_' + str(count) + '.jpg'):
                            lst.append(str(image))
                            break
                        else:
                            try:
                                # print('Saved frame number : ' + str(int(cap.get(1))))
                                cv2.imwrite('Z:/test/'+ str(file.split('/')[-1].split('.')[0]) + '_' + str(count) + '.jpg', image)
                                lst.append(str(image))
                                # print('Saved frame%d.jpg' % count)
                                # img = Image.fromarray(image)
                                # img.save('Z:/test/'+str(count)+'.png')
                                count += 1
                            except:
                                print(file)
                                pass
                    else:
                        # print('겹침')
                        # print(image)
                        pass
            # print(len(lst))
            cap.release()

        except OSError as e:
            if e.errno != e.EEXIST:
                print("Failed to create directory!!!!!")
                raise
        pbar.update(1)
# Out:
#   2%|▏         | 1731/111275 [3:19:21<271:02:41,  8.91s/it]

# %%
import glob
lst= glob.glob('Z:\*')
print(lst)
# Out:
# ['Z:\\@Recently-Snapshot', 'Z:\\@Recycle', 'Z:\\blur_dataset', 'Z:\\dataset']
